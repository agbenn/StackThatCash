# %%
import DailyStockData as stocks
import pandas as pd
import numpy as np
import datetime

# %%
x = stocks.getDailyPrice('AAPL')
allTickers = pd.read_csv('trackedTickers.csv')
allTickers
# Out:
# [*********************100%***********************]  1 of 1 completed
#      Unnamed: 0 ticker                                           compName  \
# 0             0     HR  Healthcare Realty Trust Incorporated Common Stock
# 1             0   LPCN                                      Lipocine Inc.
# 2             0   PRGO                                            Perrigo
# 3             0   DRRX                                 DURECT Corporation
# 4             0   TTMI                             TTM Technologies, Inc.
# ..          ...    ...                                                ...
# 995           0    AMD                       Advanced Micro Devices, Inc.
# 996           0    BAC           Bank of America Corporation Common Stock
# 997           0    AVP                   Avon Products, Inc. Common Stock
# 998           0      F                                         Ford Motor
# 999           0     GE                                   General Electric
#
# ...

# %%
# get current values relative to some other day's value percentage wise
# print % and print current price

# %%
priceDF.Date = priceDF.Date.astype(str)

# %%
stocksArray = []
compareDate = '2020-02-19'
allData = ['GBX','CSX', '']

for ticker in stocksArray:
    priceDF = stocks.getDailyPrice(ticker)
    allData.append(marketValueComparison(ticker, priceDF, compareDate))
    break

allData = pd.DataFrame(allData)

allData.head(20)

# %%
# if lower than recent high (1-3 weeks)
# and recent high preceded by close / lower than current low
# and previous to previous low there was a previous high, higher than the recent high all within a 90-120 day period

# %%
def getPercChange(new, old):
    return (new-old) / old

def marketValueComparison(priceDF, compareDate):
    percChange = getPercChange(priceDF.Close.iloc[-1] , priceDF.Close[compareDate])
    return percChange

def findAndrewsThrottleGap(priceDF, windowSize=100, recencyWindow=22, maxToLocalMaxDiff=-.03, recentMaxToCurrentDiff=-.06, currentPriceToMinDiff=.03):
    windowDF = priceDF.tail(windowSize)
    minPrice = windowDF.Close.min()
    maxPrice = windowDF.Close.max()
    currentPrice = windowDF.tail(1).Close.values
    # if price is close to low than high
    if abs(getPercChange(currentPrice, maxPrice)) > abs(getPercChange(currentPrice, minPrice)):    
        recentMax = windowDF.tail(recencyWindow).Close.max()
        # if recent max is lower than the max
        if getPercChange(recentMax, maxPrice) < -.03:
            # if recent max is higher than current price by 6% 
            if getPercChange(currentPrice, recentMax) < (-.06):
                # if current price is higher than min by 3%
                if getPercChange(currentPrice, minPrice) > .03:
                    if marketValueComparison(priceDF, pd.Timestamp('2020-02-19')) > -.078:
                        return 1, currentPrice
    return 0, currentPrice

# %%
priceDF = stocks.getDailyPrice('LRN')
print(findAndrewsThrottleGap(priceDF))
# Out:
# [*********************100%***********************]  1 of 1 completed
# % change since 2020-02-19 00:00:00: 0.6676352289195296
# current price: 28.700000762939453
# (1, array([28.70000076]))

# %%
allData = []

for ticker in allTickers.ticker:
    priceDF = stocks.getDailyPrice(ticker)
    signal, price = findAndrewsThrottleGap(priceDF)
    allData.append([ticker, signal, price])

allData = pd.DataFrame(allData)

allData
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TIVO: No data found, symbol may be delisted
# /Users/mastermind/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   app.launch_new_instance()
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
allData.columns = ['ticker', 'signal', 'price']

allData = allData.loc[allData.signal == 1]
allData
# Out:
#     ticker  signal                 price
# 29    MEIP       1  [2.8499999046325684]
# 73    PANW       1   [236.5399932861328]
# 75    CONE       1   [75.01000213623047]
# 128   RIGL       1  [2.4600000381469727]
# 157    NYT       1  [42.119998931884766]
# 162   UNFI       1  [16.149999618530273]
# 229   CERS       1   [6.340000152587891]
# 230   SPGI       1  [337.42999267578125]
# 245   SPPI       1  [3.4000000953674316]
# 248    TRQ       1   [7.900000095367432]
# 254   LULU       1   [333.9200134277344]
# 256   INCY       1   [89.69000244140625]
# 257   ANGI       1   [11.09000015258789]
# 268   AKAM       1              [106.75]
# 358   GNMK       1  [11.520000457763672]
# 419   WATT       1   [2.549999952316284]
# 543    CHK       1   [4.175000190734863]
# 576  LBTYK       1  [20.350000381469727]
# 591    AGI       1   [8.399999618530273]
# 622   EXEL       1  [22.290000915527344]
# 632     AU       1  [25.170000076293945]
# 751   VBIV       1   [2.549999952316284]
# ...

# %% [markdown]
# #####

# %%
#dates = priceDF.index
#priceDF = priceDF.reset_index()
#priceDF = priceDF.loc[0:22].copy()
#priceDF        
for i in range(25,35,3):
    print(i)
# Out:
# 25
# 28
# 31
# 34

# %%
KAMADF = pd.DataFrame()

KAMADF['change'] = priceDF.Close.rolling(10).agg(lambda rows: rows[-1] - rows[0])

KAMADF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-d48f42b35cdf> in <module>
#       1 KAMADF = pd.DataFrame()
#       2
# ----> 3 KAMADF['change'] = priceDF.Close.rolling(10).agg(lambda rows: rows[-1] - rows[0])
#       4
#       5 KAMADF
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/window/rolling.py in aggregate(self, func, *args, **kwargs)
#    1957     @Appender(_shared_docs["aggregate"])
#    1958     def aggregate(self, func, *args, **kwargs):
# -> 1959         return super().aggregate(func, *args, **kwargs)
#    1960
#    1961     agg = aggregate
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/window/rolling.py in aggregate(self, func, *args, **kwargs)
#     521         result, how = self._aggregate(func, *args, **kwargs)
#     522         if result is None:
# ...

# %%
KAMADF['volatility'] = priceDF.Close.rolling(2).agg(lambda rows: abs(rows[-1] - rows[0]))
KAMADF.volatility = KAMADF.volatility.fillna(0)
KAMADF.volatility = KAMADF.volatility.rolling(10).sum()

KAMADF['EfficiencyRatio'] = KAMADF.change / KAMADF.volatility

KAMADF['SmoothingConstant'] = (KAMADF.EfficiencyRatio * (2/(2+1) - 2/(30+1)) + 2/(30+1))**2

KAMADF['Price'] = priceDF.Close

KAMADF = KAMADF.dropna()
finalKAMA = []

priorKAMA = KAMADF.Price[0]

for index, row in KAMADF.iterrows():
    priorKAMA = priorKAMA + row.SmoothingConstant * (row.Price - priorKAMA)
    finalKAMA.append(priorKAMA)
    
KAMADF['KAMA'] = finalKAMA

# %%
# Out:
#               change  volatility  EfficiencyRatio  SmoothingConstant  \
# Date
# 2000-01-14 -0.102679    0.446428        -0.230000           0.005473
# 2000-01-18  0.012835    0.477678         0.026869           0.006512
# 2000-01-19  0.022879    0.416853         0.054886           0.009519
# 2000-01-20  0.165179    0.465402         0.354916           0.077411
# 2000-01-21  0.105469    0.404576         0.260690           0.049058
# ...              ...         ...              ...                ...
# 2020-10-19  2.820000   23.400002         0.120513           0.018792
# 2020-10-20  2.430000   21.590004         0.112552           0.017500
# 2020-10-21  1.900002   20.310005         0.093550           0.014604
# 2020-10-22 -1.220001   21.320007        -0.057223           0.000904
# 2020-10-23 -9.360001   20.030006        -0.467299           0.047032
#
#                  Price        KAMA
# Date
# 2000-01-14    0.896763    0.896763
# 2000-01-18    0.928013    0.928013
# ...

# %%
finalKAMA = []

priorKAMA = KAMADF.Price[0]

for index, row in KAMADF.iterrows():
    priorKAMA = priorKAMA + row.SmoothingConstant * (row.Price - priorKAMA)
    finalKAMA.append(priorKAMA)
    
KAMADF['KAMA'] = finalKAMA
KAMADF
# Out:
# /Users/mastermind/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#               change  volatility  EfficiencyRatio  SmoothingConstant  \
# Date
# 2000-01-14 -0.102679    0.446428        -0.230000           0.005473
# 2000-01-18  0.012835    0.477678         0.026869           0.006512
# 2000-01-19  0.022879    0.416853         0.054886           0.009519
# 2000-01-20  0.165179    0.465402         0.354916           0.077411
# 2000-01-21  0.105469    0.404576         0.260690           0.049058
# ...              ...         ...              ...                ...
# 2020-10-19  2.820000   23.400002         0.120513           0.018792
# ...

# %%
KAMADF.shape
# Out:
# (5228, 6)

# %%
KAMADF.loc[KAMADF.volatility.isna()].shape
# Out:
# (9, 2)

# %%
KAMADF.loc[KAMADF.change.isna()].shape
# Out:
# (9, 2)

# %%
priceDF['posDM'] = priceDF.High.diff().dropna()
priceDF['negDM'] = priceDF.Low.diff().dropna()

# normalize the directional vectors
priceDF.loc[(priceDF.posDM < 0) & (priceDF.negDM < 0),['posDM','negDM']] = 0
priceDF.loc[(priceDF.posDM < priceDF.negDM), 'posDM'] = 0
priceDF.loc[(priceDF.posDM > priceDF.negDM), 'negDM'] = 0

# %%
def customWilderSmoothing(value, offsetValue, index):
    return (offsetValue - (offsetValue / index))  + (value)

def trueRange(valueHigh, valueLow, offsetValueHigh, offsetValueLow):
    return max((valueHigh-valueLow), (valueHigh-offsetValueHigh), (offsetValueLow-valueLow))

WilderSmoothing = np.vectorize(customWilderSmoothing)
getTR = np.vectorize(trueRange)

# %%
# set one and one offset dataframe
priceDF = priceDF[2:]
offsetDF = priceDF[1:]
priceDF = priceDF[:-1]
print(offsetDF.shape)
print(priceDF.shape)
# Out:
# (5207, 8)
# (5207, 8)

# %%
priceDF['TR'] = getTR(priceDF.High, priceDF.Low, offsetDF.High, offsetDF.Low)
offsetDF = priceDF[1:]
priceDF = priceDF[:-1]
priceDF
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.802415
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.732975
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.767695
# 2000-01-10    0.910714    0.912946    0.845982    0.872768    0.754193
# 2000-01-11    0.856585    0.887277    0.808036    0.828125    0.715615
# ...                ...         ...         ...         ...         ...
# 2020-09-08  113.949997  118.989998  112.680000  112.820000  112.820000
# 2020-09-09  117.260002  119.139999  115.260002  117.320000  117.320000
# 2020-09-10  120.360001  120.500000  112.500000  113.489998  113.489998
# 2020-09-11  114.570000  115.230003  110.000000  112.000000  112.000000
# 2020-09-14  114.720001  115.930000  112.800003  115.360001  115.360001
#
#                Volume     posDM     negDM        TR
# Date
# ...

# %%
indexSeries = np.arange(len(priceDF))+ 1
indexSeries
# Out:
# array([   1,    2,    3, ..., 5204, 5205, 5206])

# %%
priceDF['+DM'] = WilderSmoothing(priceDF['posDM'], offsetDF['posDM'], indexSeries)
priceDF['-DM'] = WilderSmoothing(priceDF['negDM'], offsetDF['negDM'], indexSeries)
priceDF['TR'] = WilderSmoothing(priceDF['TR'], offsetDF['TR'], indexSeries)
priceDF
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.802415
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.732975
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.767695
# 2000-01-10    0.910714    0.912946    0.845982    0.872768    0.754193
# 2000-01-11    0.856585    0.887277    0.808036    0.828125    0.715615
# ...                ...         ...         ...         ...         ...
# 2020-09-08  113.949997  118.989998  112.680000  112.820000  112.820000
# 2020-09-09  117.260002  119.139999  115.260002  117.320000  117.320000
# 2020-09-10  120.360001  120.500000  112.500000  113.489998  113.489998
# 2020-09-11  114.570000  115.230003  110.000000  112.000000  112.000000
# 2020-09-14  114.720001  115.930000  112.800003  115.360001  115.360001
#
#                Volume     posDM     negDM         TR       +DM       -DM
# Date
# ...

# %%
priceDF['+DI'] = (priceDF['+DM']/priceDF['TR'])*100
priceDF['-DI'] = (priceDF['-DM']/priceDF['TR'])*100
    
priceDF['DIdiff'] = ((priceDF['+DI']) - (priceDF['-DI'])).abs()
priceDF['DIsum'] = ((priceDF['+DI']) + (priceDF['-DI']))
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.802415
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.732975
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.767695
# 2000-01-10    0.910714    0.912946    0.845982    0.872768    0.754193
# 2000-01-11    0.856585    0.887277    0.808036    0.828125    0.715615
# ...                ...         ...         ...         ...         ...
# 2020-09-08  113.949997  118.989998  112.680000  112.820000  112.820000
# 2020-09-09  117.260002  119.139999  115.260002  117.320000  117.320000
# 2020-09-10  120.360001  120.500000  112.500000  113.489998  113.489998
# 2020-09-11  114.570000  115.230003  110.000000  112.000000  112.000000
# 2020-09-14  114.720001  115.930000  112.800003  115.360001  115.360001
#
#                Volume     posDM     negDM         TR       +DM       -DM  \
# Date
# ...

# %%
# directional movement index
priceDF['DX'] = (priceDF['DIdiff'] / priceDF['DIsum']) * 100
print(priceDF.DX.max())
print(priceDF.DX.min())
priceDF['DX'] = priceDF['DX'].fillna(0)
# Out:
# 100.0
# 0.0

# %%
priceDF.ADX[-1]
# Out:
# 67.30300030374826

# %%
averagedDX = []
prevADX = 0

for index in range(0, len(priceDF.DX)):
    x = index + 1
    ADX = ((prevADX * ( x - 1) ) +  priceDF.DX[index]) / x
    averagedDX.append(ADX)
    prevADX = ADX

    
priceDF['ADX'] = averagedDX

priceDF = priceDF.drop(columns=['posDM', 'negDM', 'TR', '+DM', '-DM', '+DI', '-DI', 'DIdiff', 'DIsum', 'DX'])

priceDF
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2000-01-05    0.926339    0.987165    0.919643    0.928571    0.802415
# 2000-01-06    0.947545    0.955357    0.848214    0.848214    0.732975
# 2000-01-07    0.861607    0.901786    0.852679    0.888393    0.767695
# 2000-01-10    0.910714    0.912946    0.845982    0.872768    0.754193
# 2000-01-11    0.856585    0.887277    0.808036    0.828125    0.715615
# ...                ...         ...         ...         ...         ...
# 2020-09-08  113.949997  118.989998  112.680000  112.820000  112.820000
# 2020-09-09  117.260002  119.139999  115.260002  117.320000  117.320000
# 2020-09-10  120.360001  120.500000  112.500000  113.489998  113.489998
# 2020-09-11  114.570000  115.230003  110.000000  112.000000  112.000000
# 2020-09-14  114.720001  115.930000  112.800003  115.360001  115.360001
#
#                Volume         ADX
# Date
# 2000-01-05  778321600  100.000000
# ...

# %%
# within last 10 days was there an indicator flag
# is it buy or sell flag
# is it diverging or converging

# %%
# if buy flag on current date
priceCheck = priceDF[-1]

if priceCheck.Close >= priceCheck.upperBand or priceCheck.Close <= priceCheck.lowerBand:
    priceDF = priceDF[-5:]

    # buy flag
    if priceDF.loc[(priceDF.upperBand <= priceDF.Close)].shape[0] > 0:
        # is close price going further away from or getting closer to upper band
        priceDF['monoCheck'] = priceDF.Close - priceDF.upperBand
        
        # getting further away from lines
        if priceDF.monoCheck.is_monotonic_increasing:
            return 1
        else: 
            # coming back to lines
            if priceDF.monoCheck.is_monotonic_decreasing:
                return -1
            else:
                return 0
    elif priceDF.loc[(priceDF.lowerBand >= priceDF.Close)].shape[0] > 0:
        # is close price going further away from or getting closer to lower band
        priceDF['monoCheck'] = priceDF.Close - priceDF.lowerBand
        
        # getting further away
        if priceDF.monoCheck.is_monotonic_decreasing:
            return -1
        else:
            # coming back inside lines
            if priceDF.monoCheck.is_monotonic_increasing:
                return 1
            else:
                return 0
    else:
        return 0
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-08-18  114.352501  116.000000  114.007500  115.562500  115.562500
# 2020-08-19  115.982498  117.162498  115.610001  115.707497  115.707497
# 2020-08-20  115.750000  118.392502  115.732498  118.275002  118.275002
# 2020-08-21  119.262497  124.867500  119.250000  124.370003  124.370003
# 2020-08-24  128.697495  128.785004  123.937500  125.857498  125.857498
# 2020-08-25  124.697502  125.180000  123.052498  124.824997  124.824997
# 2020-08-26  126.180000  126.992500  125.082497  126.522499  126.522499
# 2020-08-27  127.142502  127.485001  123.832497  125.010002  125.010002
# 2020-08-28  126.012497  126.442497  124.577499  124.807503  124.807503
# 2020-08-31  127.580002  131.000000  126.000000  129.039993  129.039993
#
#                  Volume   upperBand   lowerBand
# Date
# 2020-08-18  105633600.0  112.699664   98.553410
# 2020-08-19  145538000.0  113.677106   99.485853
# ...
